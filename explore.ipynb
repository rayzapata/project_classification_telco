# %%
import pandas as pd
import numpy as np
from prepare import base_prep
from acquire import get_data
from explore import base_explore

# %%
df = base_explore()

# %%
df
# Out:
#       gender  is_senior  has_partner  has_partner  has_dependent  \
# 0     Female          0          Yes            1            Yes
# 1       Male          0           No            0             No
# 2     Female          0           No            0             No
# 3       Male          0          Yes            1            Yes
# 4       Male          0          Yes            1             No
# ...      ...        ...          ...          ...            ...
# 7038  Female          0          Yes            1            Yes
# 7039  Female          0           No            0             No
# 7040  Female          0           No            0             No
# 7041    Male          0           No            0             No
# 7042  Female          0           No            0             No
#
#       has_dependent phone_service_type internet_service_type  streaming_tv  \
# 0                 1     Multiple Lines                   DSL             1
# ...
